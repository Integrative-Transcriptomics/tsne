# %%
import pandas as pd
import numpy as np

#from IFD_tsne import *
from tsne_jax import *
#from utils import load_data, MidpointNormalize, equipotential_standard_normal, plot_heatmaps
from utils import load_data, plot_heatmap
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
#import tikzplotlib

from tueplots import cycler, fonts, fontsizes, bundles
from tueplots.constants import markers
from tueplots.constants.color import palettes

plt.rcParams.update(cycler.cycler(color=palettes.tue_plot))
plt.rcParams.update(fonts.aistats2022_tex(family="serif"))
plt.rcParams.update(fontsizes.aistats2022())
plt.rcParams['axes.grid'] = False

# %% [markdown]
# ### Load matrices generated in R

# %%
selected_data = pd.read_csv('datasets/AGEMAP/selected_data.txt')
selected_data = selected_data.values
labels = pd.read_csv('datasets/AGEMAP/labels.txt', header=None)
labels = labels.values.flatten().tolist()[1:]
key = random.PRNGKey(41)
#X = onp.array(random.normal(key, shape=(50, 50)))
y_guess = random.normal(key, shape=(selected_data.shape[0], 2))
#Y_star = TSNE(n_components=2, learning_rate=200, init=onp.array(y_guess), perplexity=30).fit_transform(X)
selected_data_tsne = tsne_fwd(selected_data, y_guess)
# Out:
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.22 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.05 seconds
# ===> Running optimization with exaggeration=12.00, lr=200.00 for 250 iterations...
# Iteration   50, KL divergence 1.5731, 50 iterations in 1.0308 sec
# Iteration  100, KL divergence 1.4906, 50 iterations in 0.8345 sec
# Iteration  150, KL divergence 1.4283, 50 iterations in 0.8239 sec
# Iteration  200, KL divergence 1.4272, 50 iterations in 0.8308 sec
# Iteration  250, KL divergence 1.3972, 50 iterations in 0.8221 sec
#    --> Time elapsed: 4.34 seconds
# ===> Running optimization with exaggeration=1.00, lr=200.00 for 750 iterations...
# Iteration   50, KL divergence 0.5387, 50 iterations in 0.8202 sec
# Iteration  100, KL divergence 0.3979, 50 iterations in 0.8186 sec
# Iteration  150, KL divergence 0.3507, 50 iterations in 0.8194 sec
# Iteration  200, KL divergence 0.3307, 50 iterations in 0.8227 sec
# Iteration  250, KL divergence 0.3215, 50 iterations in 0.8185 sec
# Iteration  300, KL divergence 0.3140, 50 iterations in 0.8204 sec
# Iteration  350, KL divergence 0.3110, 50 iterations in 1.0106 sec
# Iteration  400, KL divergence 0.3075, 50 iterations in 0.9861 sec
# Iteration  450, KL divergence 0.3056, 50 iterations in 1.0528 sec
# Iteration  500, KL divergence 0.3029, 50 iterations in 1.0934 sec
# Iteration  550, KL divergence 0.3007, 50 iterations in 1.1828 sec
# Iteration  600, KL divergence 0.2991, 50 iterations in 1.1808 sec
# Iteration  650, KL divergence 0.2969, 50 iterations in 1.2113 sec
# Iteration  700, KL divergence 0.2960, 50 iterations in 1.4258 sec
# Iteration  750, KL divergence 0.2952, 50 iterations in 1.4278 sec
#    --> Time elapsed: 15.49 seconds

# %%
mean = pd.read_csv('datasets/AGEMAP/mean.txt')
cov1 = pd.read_csv('datasets/AGEMAP/cov1.txt')
N = np.array(cov1.values)
cov2 = pd.read_csv('datasets/AGEMAP/cov2.txt')
D = np.array(cov2.values)

print(mean.shape, cov1.shape, cov2.shape)
# Out:
# (127, 50) (127, 127) (50, 50)

# %%
import scipy
from utils import load_data
X = scipy.stats.matrix_normal.rvs(mean, cov1, cov2)
#X, y = load_data(10)
key = random.PRNGKey(42)

y_guess = random.normal(key, shape=(X.shape[0], 2))

Y_star = tsne_fwd(X, y_guess)

X_flat, X_unflattener = flatten_util.ravel_pytree(np.array(X))   # row-wise
Y_flat, Y_unflattener = flatten_util.ravel_pytree(Y_star)
# Out:
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=12.00, lr=200.00 for 250 iterations...
# Iteration   50, KL divergence 1.8207, 50 iterations in 0.8393 sec
# Iteration  100, KL divergence 1.6942, 50 iterations in 0.7953 sec
# Iteration  150, KL divergence 1.7143, 50 iterations in 0.9096 sec
# Iteration  200, KL divergence 1.6962, 50 iterations in 0.7847 sec
# Iteration  250, KL divergence 1.7674, 50 iterations in 0.7854 sec
#    --> Time elapsed: 4.12 seconds
# ===> Running optimization with exaggeration=1.00, lr=200.00 for 750 iterations...
# Iteration   50, KL divergence 0.2085, 50 iterations in 0.7860 sec
# Iteration  100, KL divergence 0.1954, 50 iterations in 0.7904 sec
# Iteration  150, KL divergence 0.1939, 50 iterations in 0.7858 sec
# Iteration  200, KL divergence 0.1933, 50 iterations in 0.7860 sec
# Iteration  250, KL divergence 0.1929, 50 iterations in 0.7871 sec
# Iteration  300, KL divergence 0.1925, 50 iterations in 0.7869 sec
# Iteration  350, KL divergence 0.1922, 50 iterations in 0.7899 sec
# Iteration  400, KL divergence 0.1922, 50 iterations in 0.7943 sec
# Iteration  450, KL divergence 0.1920, 50 iterations in 0.7911 sec
# Iteration  500, KL divergence 0.1916, 50 iterations in 0.7978 sec
# Iteration  550, KL divergence 0.1913, 50 iterations in 0.7986 sec
# Iteration  600, KL divergence 0.1912, 50 iterations in 0.8063 sec
# Iteration  650, KL divergence 0.1911, 50 iterations in 0.8047 sec
# Iteration  700, KL divergence 0.1913, 50 iterations in 0.8046 sec
# Iteration  750, KL divergence 0.1912, 50 iterations in 0.8086 sec
#    --> Time elapsed: 11.92 seconds

# %%
labels_red = [i[:-1] for i in labels]
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cs = le.fit_transform(labels_red)
labels_set = list(set(labels_red))
labels_set.sort()

# %%
print(labels_red, '\n', labels_set, len(labels_set))
# Out:
# ['AdFA', 'AdFA', 'AdFA', 'AdFA', 'AdMA', 'AdMA', 'AdMA', 'AdMA', 'BFA', 'BFA', 'BFA', 'BFA', 'BMA', 'BMA', 'BMA', 'BMA', 'BmFA', 'BmFA', 'BmFA', 'BmMA', 'BmMA', 'BmMA', 'BmMA', 'CFA', 'CFA', 'CFA', 'CFA', 'CMA', 'CMA', 'CMA', 'CMA', 'EFA', 'EFA', 'EFA', 'EFA', 'EMA', 'EMA', 'EMA', 'EMA', 'GFA', 'GFA', 'GFA', 'GFA', 'GMA', 'GMA', 'GMA', 'GMA', 'HFA', 'HMA', 'HFA', 'HMA', 'HFA', 'HMA', 'HFA', 'HMA', 'HiFA', 'HiFA', 'HiFA', 'HiFA', 'HiMA', 'HiMA', 'HiMA', 'HiMA', 'KFA', 'KFA', 'KFA', 'KFA', 'KMA', 'KMA', 'KMA', 'KMA', 'LFA', 'LFA', 'LFA', 'LFA', 'LMA', 'LMA', 'LMA', 'LMA', 'LuFA', 'LuFA', 'LuFA', 'LuFA', 'LuMA', 'LuMA', 'LuMA', 'LuMA', 'SFA', 'SFA', 'SFA', 'SFA', 'SMA', 'SMA', 'SMA', 'SMA', 'SpFA', 'SpFA', 'SpFA', 'SpFA', 'SpMA', 'SpMA', 'SpMA', 'SpMA', 'StFA', 'StFA', 'StFA', 'StFA', 'StMA', 'StMA', 'StMA', 'StMA', 'TFA', 'TFA', 'TFA', 'TFA', 'TMA', 'TMA', 'TMA', 'TMA', 'MsFA', 'MsFA', 'MsFA', 'MsFA', 'MsMA', 'MsMA', 'MsMA', 'MsMA']
#  ['AdFA', 'AdMA', 'BFA', 'BMA', 'BmFA', 'BmMA', 'CFA', 'CMA', 'EFA', 'EMA', 'GFA', 'GMA', 'HFA', 'HMA', 'HiFA', 'HiMA', 'KFA', 'KMA', 'LFA', 'LMA', 'LuFA', 'LuMA', 'MsFA', 'MsMA', 'SFA', 'SMA', 'SpFA', 'SpMA', 'StFA', 'StMA', 'TFA', 'TMA'] 32

# %%
import matplotlib
cmap_b = matplotlib.colormaps['tab20b'].colors
cmap_c = matplotlib.colormaps['tab20c'].colors
cmap = matplotlib.colors.ListedColormap(onp.vstack([cmap_b, cmap_c]), name='my_colormap')

# %%
f = plt.figure()
scatter = plt.scatter(*Y_star.T, c = cs, cmap = cmap)
plt.legend(handles=scatter.legend_elements(num=len(labels_set))[0], labels=labels_set, bbox_to_anchor=(1.04, 1), loc="upper left")
#plt.legend(handles=scatter.legend_elements()[0], labels=labels)
#plt.legend(labels)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x7fd8e8178b80> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/pyplot.py:120, in _draw_all_if_interactive()
#     118 def _draw_all_if_interactive():
#     119     if matplotlib.is_interactive():
# --> 120         draw_all()
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/backend_bases.py:2078, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2076 if not self._is_idle_drawing:
#    2077     with self._idle_draw_cntx():
# -> 2078         self.draw(*args, **kwargs)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/figure.py:3125, in Figure.draw(self, renderer)
#    3122         # ValueError can occur when resizing a window.
#    3124 self.patch.draw(renderer)
# -> 3125 mimage._draw_list_compositing_images(
#    3126     renderer, self, artists, self.suppressComposite)
#    3128 for sfig in self.subfigs:
#    3129     sfig.draw(renderer)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/axes/_base.py:3066, in _AxesBase.draw(self, renderer)
#    3063 if artists_rasterized:
#    3064     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3066 mimage._draw_list_compositing_images(
#    3067     renderer, self, artists, self.figure.suppressComposite)
#    3069 renderer.close_group('axes')
#    3070 self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/legend.py:741, in Legend.draw(self, renderer)
#     738     Shadow(self.legendPatch, 2, -2).draw(renderer)
#     740 self.legendPatch.draw(renderer)
# --> 741 self._legend_box.draw(renderer)
#     743 renderer.close_group('legend')
#     744 self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/offsetbox.py:416, in OffsetBox.draw(self, renderer)
#     414 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     415     c.set_offset((px + ox, py + oy))
# --> 416     c.draw(renderer)
#     417 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     418 self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/offsetbox.py:416, in OffsetBox.draw(self, renderer)
#     414 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     415     c.set_offset((px + ox, py + oy))
# --> 416     c.draw(renderer)
#     417 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     418 self.stale = False
#
#     [... skipping similar frames: _prevent_rasterization.<locals>.draw_wrapper at line 39 (2 times), OffsetBox.draw at line 416 (1 times)]
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/offsetbox.py:416, in OffsetBox.draw(self, renderer)
#     414 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     415     c.set_offset((px + ox, py + oy))
# --> 416     c.draw(renderer)
#     417 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     418 self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/offsetbox.py:821, in TextArea.draw(self, renderer)
#     819 def draw(self, renderer):
#     820     # docstring inherited
# --> 821     self._text.draw(renderer)
#     822     _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     823     self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/text.py:796, in Text.draw(self, renderer)
#     793     textrenderer = renderer
#     795 if self.get_usetex():
# --> 796     textrenderer.draw_tex(gc, x, y, clean_line,
#     797                           self._fontproperties, angle,
#     798                           mtext=mtext)
#     799 else:
#     800     textrenderer.draw_text(gc, x, y, clean_line,
#     801                            self._fontproperties, angle,
#     802                            ismath=ismath, mtext=mtext)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:249, in RendererAgg.draw_tex(self, gc, x, y, s, prop, angle, mtext)
#     245 size = prop.get_size_in_points()
#     247 texmanager = self.get_texmanager()
# --> 249 Z = texmanager.get_grey(s, size, self.dpi)
#     250 Z = np.array(Z * 255.0, np.uint8)
#     252 w, h, d = self.get_text_width_height_descent(s, prop, ismath="TeX")
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/texmanager.py:341, in TexManager.get_grey(cls, tex, fontsize, dpi)
#     339 alpha = cls._grey_arrayd.get(key)
#     340 if alpha is None:
# --> 341     pngfile = cls.make_png(tex, fontsize, dpi)
#     342     rgba = mpl.image.imread(os.path.join(cls.texcache, pngfile))
#     343     cls._grey_arrayd[key] = alpha = rgba[:, :, -1]
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/texmanager.py:314, in TexManager.make_png(cls, tex, fontsize, dpi)
#     307 @classmethod
#     308 def make_png(cls, tex, fontsize, dpi):
#     309     """
#     310     Generate a png file containing latex's rendering of tex string.
#     311
#     312     Return the file name.
#     313     """
# --> 314     basefile = cls.get_basefile(tex, fontsize, dpi)
#     315     pngfile = '%s.png' % basefile
#     316     # see get_rgba for a discussion of the background
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/texmanager.py:186, in TexManager.get_basefile(cls, tex, fontsize, dpi)
#     183 for i in range(0, num_letters*num_levels, num_letters):
#     184     filepath = filepath / Path(filehash[i:i+2])
# --> 186 filepath.mkdir(parents=True, exist_ok=True)
#     187 return os.path.join(filepath, filehash)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/pathlib.py:1116, in Path.mkdir(self, mode, parents, exist_ok)
#    1112 """
#    1113 Create a new directory at this given path.
#    1114 """
#    1115 try:
# -> 1116     os.mkdir(self, mode)
#    1117 except FileNotFoundError:
#    1118     if not parents or self.parent == self:
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7fd8d8367920> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/IPython/core/display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/IPython/core/formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/IPython/core/formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/IPython/core/formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/backend_bases.py:2362, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2358 try:
#    2359     # _get_renderer may change the figure dpi (as vector formats
#    2360     # force the figure dpi to 72), so we need to set it again here.
#    2361     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2362         result = print_method(
#    2363             filename,
#    2364             facecolor=facecolor,
#    2365             edgecolor=edgecolor,
#    2366             orientation=orientation,
#    2367             bbox_inches_restore=_bbox_inches_restore,
#    2368             **kwargs)
#    2369 finally:
#    2370     if bbox_inches and restore_bbox:
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/backend_bases.py:2228, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2224     optional_kws = {  # Passed by print_figure for other renderers.
#    2225         "dpi", "facecolor", "edgecolor", "orientation",
#    2226         "bbox_inches_restore"}
#    2227     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2228     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2229         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2230 else:  # Let third-parties do as they see fit.
#    2231     print_method = meth
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:509, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     462 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     463     """
#     464     Write the figure to a PNG file.
#     465
#    (...)    507         *metadata*, including the default 'Software' key.
#     508     """
# --> 509     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:457, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     452 def _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata=None):
#     453     """
#     454     Draw the canvas, then save it using `.image.imsave` (to which
#     455     *pil_kwargs* and *metadata* are forwarded).
#     456     """
# --> 457     FigureCanvasAgg.draw(self)
#     458     mpl.image.imsave(
#     459         filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/figure.py:3125, in Figure.draw(self, renderer)
#    3122         # ValueError can occur when resizing a window.
#    3124 self.patch.draw(renderer)
# -> 3125 mimage._draw_list_compositing_images(
#    3126     renderer, self, artists, self.suppressComposite)
#    3128 for sfig in self.subfigs:
#    3129     sfig.draw(renderer)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/axes/_base.py:3066, in _AxesBase.draw(self, renderer)
#    3063 if artists_rasterized:
#    3064     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3066 mimage._draw_list_compositing_images(
#    3067     renderer, self, artists, self.figure.suppressComposite)
#    3069 renderer.close_group('axes')
#    3070 self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/image.py:131, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129 if not_composite or not has_images:
#     130     for a in artists:
# --> 131         a.draw(renderer)
#     132 else:
#     133     # Composite any adjacent images together
#     134     image_group = []
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/legend.py:741, in Legend.draw(self, renderer)
#     738     Shadow(self.legendPatch, 2, -2).draw(renderer)
#     740 self.legendPatch.draw(renderer)
# --> 741 self._legend_box.draw(renderer)
#     743 renderer.close_group('legend')
#     744 self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/offsetbox.py:416, in OffsetBox.draw(self, renderer)
#     414 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     415     c.set_offset((px + ox, py + oy))
# --> 416     c.draw(renderer)
#     417 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     418 self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/offsetbox.py:416, in OffsetBox.draw(self, renderer)
#     414 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     415     c.set_offset((px + ox, py + oy))
# --> 416     c.draw(renderer)
#     417 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     418 self.stale = False
#
#     [... skipping similar frames: _prevent_rasterization.<locals>.draw_wrapper at line 39 (2 times), OffsetBox.draw at line 416 (1 times)]
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/offsetbox.py:416, in OffsetBox.draw(self, renderer)
#     414 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     415     c.set_offset((px + ox, py + oy))
# --> 416     c.draw(renderer)
#     417 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     418 self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:39, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      36     renderer.stop_rasterizing()
#      37     renderer._rasterizing = False
# ---> 39 return draw(artist, renderer, *args, **kwargs)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/offsetbox.py:821, in TextArea.draw(self, renderer)
#     819 def draw(self, renderer):
#     820     # docstring inherited
# --> 821     self._text.draw(renderer)
#     822     _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     823     self.stale = False
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/text.py:796, in Text.draw(self, renderer)
#     793     textrenderer = renderer
#     795 if self.get_usetex():
# --> 796     textrenderer.draw_tex(gc, x, y, clean_line,
#     797                           self._fontproperties, angle,
#     798                           mtext=mtext)
#     799 else:
#     800     textrenderer.draw_text(gc, x, y, clean_line,
#     801                            self._fontproperties, angle,
#     802                            ismath=ismath, mtext=mtext)
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:249, in RendererAgg.draw_tex(self, gc, x, y, s, prop, angle, mtext)
#     245 size = prop.get_size_in_points()
#     247 texmanager = self.get_texmanager()
# --> 249 Z = texmanager.get_grey(s, size, self.dpi)
#     250 Z = np.array(Z * 255.0, np.uint8)
#     252 w, h, d = self.get_text_width_height_descent(s, prop, ismath="TeX")
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/texmanager.py:341, in TexManager.get_grey(cls, tex, fontsize, dpi)
#     339 alpha = cls._grey_arrayd.get(key)
#     340 if alpha is None:
# --> 341     pngfile = cls.make_png(tex, fontsize, dpi)
#     342     rgba = mpl.image.imread(os.path.join(cls.texcache, pngfile))
#     343     cls._grey_arrayd[key] = alpha = rgba[:, :, -1]
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/texmanager.py:328, in TexManager.make_png(cls, tex, fontsize, dpi)
#     325     if (getattr(mpl, "_called_from_pytest", False) and
#     326             mpl._get_executable_info("dvipng").raw_version != "1.16"):
#     327         cmd.insert(1, "--freetype0")
# --> 328     cls._run_checked_subprocess(cmd, tex)
#     329 return pngfile
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/site-packages/matplotlib/texmanager.py:255, in TexManager._run_checked_subprocess(cls, command, tex, cwd)
#     253 _log.debug(cbook._pformat_subprocess(command))
#     254 try:
# --> 255     report = subprocess.check_output(
#     256         command, cwd=cwd if cwd is not None else cls.texcache,
#     257         stderr=subprocess.STDOUT)
#     258 except FileNotFoundError as exc:
#     259     raise RuntimeError(
#     260         'Failed to process string with tex because {} could not be '
#     261         'found'.format(command[0])) from exc
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File /local_scratch/zabel/miniconda3/envs/tsne/lib/python3.11/subprocess.py:1196, in Popen.communicate(self, input, timeout)
#    1194     self._stdin_write(input)
#    1195 elif self.stdout:
# -> 1196     stdout = self.stdout.read()
#    1197     self.stdout.close()
#    1198 elif self.stderr:
#
# KeyboardInterrupt:

# %%
cov_final = compute_cov(X_flat, Y_flat, X_unflattener, Y_unflattener, D, N, perplexity=30.0)
cov_final = cov_final + 1e-3*np.eye(len(cov_final))

# %%
plot_heatmap(cov_final)
# Out:
# <Axes: >

# %%
from utils import equipotential_standard_normal_within_one_std

S = equipotential_standard_normal_within_one_std(2 * Y_star.shape[0], 20)
L, lower = jax.scipy.linalg.cho_factor(cov_final, lower=True)
samples = np.transpose(np.transpose(np.dot(L, S))+Y_flat)

# %%
from animate_ifd import *
animate(samples, labels_red, 'datasets/AGEMAP/animation.gif', cmap)

# %%
draw_and_plot_samples(Y_flat, Y_unflattener, cov_final, 100, 'datasets/AGEMAP/tnse_distr.pdf', cmap)
# Out:
# (100, 254)
