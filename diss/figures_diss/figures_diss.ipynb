# %%
from IFD_tsne import *
#from utils import load_data, MidpointNormalize, equipotential_standard_normal, plot_heatmaps
from utils import MidpointNormalize, load_data
import matplotlib.pyplot as plt
import tikzplotlib

from tueplots import cycler, fonts, fontsizes, bundles
from tueplots.constants import markers
from tueplots.constants.color import palettes

plt.rcParams.update(cycler.cycler(color=palettes.tue_plot))
plt.rcParams.update(fonts.aistats2022_tex(family="serif"))
plt.rcParams.update(fontsizes.aistats2022())
plt.rcParams['axes.grid'] = False

# %%
def KL_divergence(X_flat, Y_flat, X_unflattener, Y_unflattener):
    """
    (R^nxp x R^nxp)--> R
    """
    X = X_unflattener(X_flat)
    Y = Y_unflattener(Y_flat)
    learning_rate, perplexity = (200, 30.0)
    P = x2p(X, tol=1e-5, perplexity=perplexity)
    P = (P + np.transpose(P))
    P = P / np.sum(P)      # Why don't we devide by 2N as described everywhere?
    P = np.maximum(P, 1e-12)
    Q, _ = y2q(Y)
    return np.sum(P * (np.log(P+1e-10) - np.log(Q+1e-10)))

# %%
#X, y = make_blobs(n_samples=50, n_features=50, centers=4, random_state=0, shuffle=False, cluster_std=[0.1, 3, 3, 3])
X, y = load_data(50)
print(X)
key = random.PRNGKey(41)
#X = onp.array(random.normal(key, shape=(50, 50)))
y_guess = random.normal(key, shape=(X.shape[0], 2))
#Y_star = TSNE(n_components=2, learning_rate=200, init=onp.array(y_guess), perplexity=30).fit_transform(X)
Y_star = tsne_fwd(X, y_guess)

X_flat, X_unflattener = flatten_util.ravel_pytree(X)   # row-wise
Y_flat, Y_unflattener = flatten_util.ravel_pytree(Y_star)
# Out:
# [[-1.0474224   1.08699073 -2.17554182 ...  0.33163636  0.17563572
#    0.61333185]
#  [ 1.2289465   1.68343882 -1.75473847 ...  1.10487508 -0.73511061
#    0.43998502]
#  [-1.15958102  1.62390083  1.90808822 ...  0.3528243   0.54256161
#   -0.15265831]
#  ...
#  [-2.08291216  0.58000551 -2.77353786 ... -0.47454766  0.28762683
#   -0.32250227]
#  [-3.61993229 -1.91357412  0.29490532 ... -0.19141316 -0.10925214
#   -0.03719429]
#  [-0.18205928 -1.39208594 -4.07052893 ...  0.24521957 -0.48679782
#    0.48365602]]
# ===> Finding 49 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=12.00, lr=200.00 for 250 iterations...
# Iteration   50, KL divergence 0.9840, 50 iterations in 0.3528 sec
# Iteration  100, KL divergence 0.9697, 50 iterations in 0.2664 sec
# Iteration  150, KL divergence 0.9966, 50 iterations in 0.3034 sec
# Iteration  200, KL divergence 0.9606, 50 iterations in 0.2747 sec
# Iteration  250, KL divergence 0.9299, 50 iterations in 0.2866 sec
#    --> Time elapsed: 1.48 seconds
# ===> Running optimization with exaggeration=1.00, lr=200.00 for 750 iterations...
# Iteration   50, KL divergence 0.2192, 50 iterations in 0.4844 sec
# Iteration  100, KL divergence 0.2192, 50 iterations in 0.2796 sec
# Iteration  150, KL divergence 0.2192, 50 iterations in 0.2607 sec
# Iteration  200, KL divergence 0.2192, 50 iterations in 0.2935 sec
# Iteration  250, KL divergence 0.2192, 50 iterations in 0.3442 sec
# Iteration  300, KL divergence 0.2192, 50 iterations in 0.2738 sec
# Iteration  350, KL divergence 0.2192, 50 iterations in 0.2882 sec
# Iteration  400, KL divergence 0.2192, 50 iterations in 0.2719 sec
# Iteration  450, KL divergence 0.2192, 50 iterations in 0.3190 sec
# Iteration  500, KL divergence 0.2192, 50 iterations in 0.3202 sec
# Iteration  550, KL divergence 0.2192, 50 iterations in 0.2928 sec
# Iteration  600, KL divergence 0.2192, 50 iterations in 0.3039 sec
# Iteration  650, KL divergence 0.2192, 50 iterations in 0.3026 sec
# Iteration  700, KL divergence 0.2192, 50 iterations in 0.2691 sec
# Iteration  750, KL divergence 0.2192, 50 iterations in 0.3070 sec
#    --> Time elapsed: 4.61 seconds

# %%
fun = lambda y: KL_divergence(X_flat, y, X_unflattener, Y_unflattener)
H = jax.hessian(fun)(Y_flat)
# Out:
# Computing pairwise distances...
# Starting binary search
# Entered binary search function

# %%
u, s, w = np.linalg.svd(H)

# %%
print(KL_divergence(X_flat, u[:, 97] + u[:, 98] + u[:, 99] + Y_flat, X_unflattener, Y_unflattener))
print(KL_divergence(X_flat, u[:, 97] + 3*u[:, 98] + 10*u[:, 99] + Y_flat, X_unflattener, Y_unflattener))
# Out:
# Computing pairwise distances...
# Starting binary search
# Entered binary search function
# 0.15162385
# Computing pairwise distances...
# Starting binary search
# Entered binary search function
# 0.15162417

# %%
f, ax1 = plt.subplots(1, 1, figsize=(3, 3))
ax1.scatter([i for i in range(1, len(s)+1)], np.flip(np.sort(np.abs(s))))
ax1.set_yscale('log')
ax1.set_xlabel('singular values')
#tikzplotlib.save("figures_diss/singular_values.pgf")
# Out:
# Text(0.5, 0, 'singular values')

# %%
f, ax = plt.subplots(1, 1, figsize=(3, 3))
ax.scatter(*Y_star.T, c='black')
ax.set_xlabel('TSNE 1')
ax.set_ylabel('TSNE 2')
for i, j in enumerate(Y_star):
  vector = Y_unflattener(u[:, 97])*1.5
  ax.plot([j[0], (j+vector[i])[0]] , [j[1], (j+vector[i])[1]], color = palettes.tue_plot[0])
  vector = Y_unflattener(u[:, 98])*1.5
  ax.plot([j[0], (j+vector[i])[0]] , [j[1], (j+vector[i])[1]], color = palettes.tue_plot[1])
  vector = Y_unflattener(u[:, 99])*1.5
  ax.plot([j[0], (j+vector[i])[0]] , [j[1], (j+vector[i])[1]], color = palettes.tue_plot[2])
tikzplotlib.save("figures_diss/singular_vectors.pgf")

# %%
f, ax = plt.subplots(1, 1, figsize=(3, 3))
ax.scatter(*Y_star.T, c='black')
ax.set_xlabel('TSNE 1')
ax.set_ylabel('TSNE 2')
j = Y_star[0]
vector = Y_unflattener(u[:, 97])
ax.plot([j[0], (j+vector[0])[0]] , [j[1], (j+vector[0])[1]], color = palettes.tue_plot[0])
#vector = Y_unflattener(u[:, 98])
#ax.arrow(j[0], j[1], vector[i, 0], vector[i, 1], color = palettes.tue_plot[1])
#vector = Y_unflattener(u[:, 99])
#ax.arrow(j[0], j[1], vector[i, 0], vector[i, 1], color = palettes.tue_plot[2])
#tikzplotlib.save("figures_diss/singular_vectors.pgf")

# %%
from scipy.optimize import fmin
import numpy as np

y_range = np.linspace(-1, 1, 100)
zs = []
cs = []

def loss(x, y):
  alpha = np.deg2rad(15)
  return ((4 - 2.1*(np.sin(alpha)*x + np.cos(alpha)*y)**2 + (np.sin(alpha)*x + np.cos(alpha)*y)**4/3)*(np.sin(alpha)*x + np.cos(alpha)*y)**2 + (np.sin(alpha)*x + np.cos(alpha)*y)*(np.cos(alpha)*x - np.sin(alpha)*y)+(-4 + 4*(np.cos(alpha)*x - np.sin(alpha)*y)**2)*(np.cos(alpha)*x - np.sin(alpha)*y)**2)

for y_test in y_range:
  fun = lambda z: loss(y_test, z)
  z = fmin(fun, 0.0)[0]
  print(z)
  zs.append(z)
  cs.append(loss(y_test, z))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.199291
#          Iterations: 19
#          Function evaluations: 38
# 0.11643750000000008
# Optimization terminated successfully.
#          Current function value: 0.038742
#          Iterations: 19
#          Function evaluations: 38
# 0.13181250000000008
# Optimization terminated successfully.
#          Current function value: -0.108916
#          Iterations: 19
#          Function evaluations: 38
# 0.1463750000000001
# Optimization terminated successfully.
#          Current function value: -0.244007
#          Iterations: 20
#          Function evaluations: 40
# 0.16000000000000011
# Optimization terminated successfully.
#          Current function value: -0.366874
#          Iterations: 20
#          Function evaluations: 40
# 0.17281250000000012
# Optimization terminated successfully.
#          Current function value: -0.477880
#          Iterations: 20
#          Function evaluations: 40
# 0.18487500000000012
# Optimization terminated successfully.
#          Current function value: -0.577399
#          Iterations: 20
#          Function evaluations: 40
# 0.19612500000000016
# Optimization terminated successfully.
#          Current function value: -0.665821
#          Iterations: 20
#          Function evaluations: 40
# 0.20668750000000016
# Optimization terminated successfully.
#          Current function value: -0.743545
#          Iterations: 20
#          Function evaluations: 40
# 0.21650000000000016
# Optimization terminated successfully.
#          Current function value: -0.810978
#          Iterations: 21
#          Function evaluations: 42
# 0.22556250000000017
# Optimization terminated successfully.
#          Current function value: -0.868537
#          Iterations: 21
#          Function evaluations: 42
# 0.2339375000000002
# Optimization terminated successfully.
#          Current function value: -0.916644
#          Iterations: 21
#          Function evaluations: 42
# 0.2416250000000002
# Optimization terminated successfully.
#          Current function value: -0.955726
#          Iterations: 21
#          Function evaluations: 42
# 0.24856250000000019
# Optimization terminated successfully.
#          Current function value: -0.986216
#          Iterations: 21
#          Function evaluations: 42
# 0.2548125000000002
# Optimization terminated successfully.
#          Current function value: -1.008552
#          Iterations: 21
#          Function evaluations: 42
# 0.2603125000000003
# Optimization terminated successfully.
#          Current function value: -1.023173
#          Iterations: 21
#          Function evaluations: 42
# 0.2651250000000003
# Optimization terminated successfully.
#          Current function value: -1.030522
#          Iterations: 21
#          Function evaluations: 42
# 0.26918750000000025
# Optimization terminated successfully.
#          Current function value: -1.031045
#          Iterations: 21
#          Function evaluations: 42
# 0.27256250000000026
# Optimization terminated successfully.
#          Current function value: -1.025189
#          Iterations: 21
#          Function evaluations: 42
# 0.2751250000000003
# Optimization terminated successfully.
#          Current function value: -1.013402
#          Iterations: 21
#          Function evaluations: 42
# 0.27700000000000025
# Optimization terminated successfully.
#          Current function value: -0.996135
#          Iterations: 21
#          Function evaluations: 42
# 0.27806250000000027
# Optimization terminated successfully.
#          Current function value: -0.973838
#          Iterations: 21
#          Function evaluations: 42
# 0.2783125000000003
# Optimization terminated successfully.
#          Current function value: -0.946962
#          Iterations: 21
#          Function evaluations: 42
# 0.27781250000000024
# Optimization terminated successfully.
#          Current function value: -0.915957
#          Iterations: 21
#          Function evaluations: 42
# 0.2765000000000003
# Optimization terminated successfully.
#          Current function value: -0.881275
#          Iterations: 21
#          Function evaluations: 42
# 0.27437500000000026
# Optimization terminated successfully.
#          Current function value: -0.843362
#          Iterations: 21
#          Function evaluations: 42
# 0.2715000000000003
# Optimization terminated successfully.
#          Current function value: -0.802666
#          Iterations: 21
#          Function evaluations: 42
# 0.26775000000000027
# Optimization terminated successfully.
#          Current function value: -0.759630
#          Iterations: 21
#          Function evaluations: 42
# 0.26325000000000026
# Optimization terminated successfully.
#          Current function value: -0.714693
#          Iterations: 21
#          Function evaluations: 42
# 0.25793750000000026
# Optimization terminated successfully.
#          Current function value: -0.668290
#          Iterations: 21
#          Function evaluations: 42
# 0.2518125000000002
# Optimization terminated successfully.
#          Current function value: -0.620851
#          Iterations: 21
#          Function evaluations: 42
# 0.2449375000000002
# Optimization terminated successfully.
#          Current function value: -0.572795
#          Iterations: 21
#          Function evaluations: 42
# 0.23725000000000018
# Optimization terminated successfully.
#          Current function value: -0.524536
#          Iterations: 21
#          Function evaluations: 42
# 0.22887500000000016
# Optimization terminated successfully.
#          Current function value: -0.476476
#          Iterations: 20
#          Function evaluations: 40
# 0.21981250000000016
# Optimization terminated successfully.
#          Current function value: -0.429006
#          Iterations: 20
#          Function evaluations: 40
# 0.21006250000000015
# Optimization terminated successfully.
#          Current function value: -0.382504
#          Iterations: 20
#          Function evaluations: 40
# 0.19962500000000016
# Optimization terminated successfully.
#          Current function value: -0.337332
#          Iterations: 20
#          Function evaluations: 40
# 0.18856250000000013
# Optimization terminated successfully.
#          Current function value: -0.293836
#          Iterations: 20
#          Function evaluations: 40
# 0.17700000000000013
# Optimization terminated successfully.
#          Current function value: -0.252346
#          Iterations: 20
#          Function evaluations: 40
# 0.1648125000000001
# Optimization terminated successfully.
#          Current function value: -0.213171
#          Iterations: 19
#          Function evaluations: 38
# 0.15218750000000011
# Optimization terminated successfully.
#          Current function value: -0.176599
#          Iterations: 19
#          Function evaluations: 38
# 0.1390625000000001
# Optimization terminated successfully.
#          Current function value: -0.142898
#          Iterations: 19
#          Function evaluations: 38
# 0.12550000000000008
# Optimization terminated successfully.
#          Current function value: -0.112310
#          Iterations: 18
#          Function evaluations: 36
# 0.11162500000000007
# Optimization terminated successfully.
#          Current function value: -0.085055
#          Iterations: 18
#          Function evaluations: 36
# 0.09743750000000007
# Optimization terminated successfully.
#          Current function value: -0.061328
#          Iterations: 18
#          Function evaluations: 36
# 0.08287500000000005
# Optimization terminated successfully.
#          Current function value: -0.041295
#          Iterations: 17
#          Function evaluations: 34
# 0.06818750000000004
# Optimization terminated successfully.
#          Current function value: -0.025097
#          Iterations: 16
#          Function evaluations: 32
# 0.05318750000000002
# Optimization terminated successfully.
#          Current function value: -0.012850
#          Iterations: 15
#          Function evaluations: 30
# 0.03812500000000001
# Optimization terminated successfully.
#          Current function value: -0.004637
#          Iterations: 14
#          Function evaluations: 28
# 0.022937500000000006
# Optimization terminated successfully.
#          Current function value: -0.000516
#          Iterations: 11
#          Function evaluations: 22
# 0.007625000000000003
# Optimization terminated successfully.
#          Current function value: -0.000516
#          Iterations: 11
#          Function evaluations: 22
# -0.007625000000000002
# Optimization terminated successfully.
#          Current function value: -0.004637
#          Iterations: 14
#          Function evaluations: 28
# -0.022937500000000006
# Optimization terminated successfully.
#          Current function value: -0.012850
#          Iterations: 15
#          Function evaluations: 30
# -0.03812500000000001
# Optimization terminated successfully.
#          Current function value: -0.025097
#          Iterations: 16
#          Function evaluations: 32
# -0.053187500000000006
# Optimization terminated successfully.
#          Current function value: -0.041295
#          Iterations: 17
#          Function evaluations: 34
# -0.06818750000000001
# Optimization terminated successfully.
#          Current function value: -0.061328
#          Iterations: 18
#          Function evaluations: 36
# -0.08287500000000002
# Optimization terminated successfully.
#          Current function value: -0.085055
#          Iterations: 18
#          Function evaluations: 36
# -0.09743750000000004
# Optimization terminated successfully.
#          Current function value: -0.112310
#          Iterations: 19
#          Function evaluations: 38
# -0.11162500000000004
# Optimization terminated successfully.
#          Current function value: -0.142898
#          Iterations: 19
#          Function evaluations: 38
# -0.12550000000000006
# Optimization terminated successfully.
#          Current function value: -0.176599
#          Iterations: 19
#          Function evaluations: 38
# -0.13906250000000006
# Optimization terminated successfully.
#          Current function value: -0.213171
#          Iterations: 19
#          Function evaluations: 38
# -0.1521875000000001
# Optimization terminated successfully.
#          Current function value: -0.252346
#          Iterations: 20
#          Function evaluations: 40
# -0.16481250000000008
# Optimization terminated successfully.
#          Current function value: -0.293836
#          Iterations: 20
#          Function evaluations: 40
# -0.1770000000000001
# Optimization terminated successfully.
#          Current function value: -0.337332
#          Iterations: 20
#          Function evaluations: 40
# -0.1885625000000001
# Optimization terminated successfully.
#          Current function value: -0.382504
#          Iterations: 20
#          Function evaluations: 40
# -0.1996250000000001
# Optimization terminated successfully.
#          Current function value: -0.429006
#          Iterations: 20
#          Function evaluations: 40
# -0.21006250000000012
# Optimization terminated successfully.
#          Current function value: -0.476476
#          Iterations: 20
#          Function evaluations: 40
# -0.21981250000000013
# Optimization terminated successfully.
#          Current function value: -0.524536
#          Iterations: 21
#          Function evaluations: 42
# -0.22887500000000016
# Optimization terminated successfully.
#          Current function value: -0.572795
#          Iterations: 21
#          Function evaluations: 42
# -0.23725000000000016
# Optimization terminated successfully.
#          Current function value: -0.620851
#          Iterations: 21
#          Function evaluations: 42
# -0.24493750000000017
# Optimization terminated successfully.
#          Current function value: -0.668290
#          Iterations: 21
#          Function evaluations: 42
# -0.25181250000000016
# Optimization terminated successfully.
#          Current function value: -0.714693
#          Iterations: 21
#          Function evaluations: 42
# -0.25793750000000015
# Optimization terminated successfully.
#          Current function value: -0.759630
#          Iterations: 21
#          Function evaluations: 42
# -0.2632500000000002
# Optimization terminated successfully.
#          Current function value: -0.802666
#          Iterations: 21
#          Function evaluations: 42
# -0.26775000000000015
# Optimization terminated successfully.
#          Current function value: -0.843362
#          Iterations: 21
#          Function evaluations: 42
# -0.2715000000000002
# Optimization terminated successfully.
#          Current function value: -0.881275
#          Iterations: 21
#          Function evaluations: 42
# -0.2743750000000002
# Optimization terminated successfully.
#          Current function value: -0.915957
#          Iterations: 21
#          Function evaluations: 42
# -0.2765000000000002
# Optimization terminated successfully.
#          Current function value: -0.946962
#          Iterations: 21
#          Function evaluations: 42
# -0.2778125000000002
# Optimization terminated successfully.
#          Current function value: -0.973838
#          Iterations: 21
#          Function evaluations: 42
# -0.2783125000000002
# Optimization terminated successfully.
#          Current function value: -0.996135
#          Iterations: 21
#          Function evaluations: 42
# -0.2780625000000002
# Optimization terminated successfully.
#          Current function value: -1.013402
#          Iterations: 21
#          Function evaluations: 42
# -0.2770000000000002
# Optimization terminated successfully.
#          Current function value: -1.025189
#          Iterations: 21
#          Function evaluations: 42
# -0.2751250000000002
# Optimization terminated successfully.
#          Current function value: -1.031045
#          Iterations: 21
#          Function evaluations: 42
# -0.27256250000000015
# Optimization terminated successfully.
#          Current function value: -1.030522
#          Iterations: 21
#          Function evaluations: 42
# -0.2691875000000002
# Optimization terminated successfully.
#          Current function value: -1.023173
#          Iterations: 21
#          Function evaluations: 42
# -0.26512500000000017
# Optimization terminated successfully.
#          Current function value: -1.008552
#          Iterations: 21
#          Function evaluations: 42
# -0.26031250000000017
# Optimization terminated successfully.
#          Current function value: -0.986216
#          Iterations: 21
#          Function evaluations: 42
# -0.25481250000000016
# Optimization terminated successfully.
#          Current function value: -0.955726
#          Iterations: 21
#          Function evaluations: 42
# -0.24856250000000016
# Optimization terminated successfully.
#          Current function value: -0.916644
#          Iterations: 21
#          Function evaluations: 42
# -0.24162500000000015
# Optimization terminated successfully.
#          Current function value: -0.868537
#          Iterations: 21
#          Function evaluations: 42
# -0.23393750000000016
# Optimization terminated successfully.
#          Current function value: -0.810978
#          Iterations: 21
#          Function evaluations: 42
# -0.22556250000000014
# Optimization terminated successfully.
#          Current function value: -0.743545
#          Iterations: 20
#          Function evaluations: 40
# -0.21650000000000014
# Optimization terminated successfully.
#          Current function value: -0.665821
#          Iterations: 20
#          Function evaluations: 40
# -0.20668750000000014
# Optimization terminated successfully.
#          Current function value: -0.577399
#          Iterations: 20
#          Function evaluations: 40
# -0.1961250000000001
# Optimization terminated successfully.
#          Current function value: -0.477880
#          Iterations: 20
#          Function evaluations: 40
# -0.18487500000000012
# Optimization terminated successfully.
#          Current function value: -0.366874
#          Iterations: 20
#          Function evaluations: 40
# -0.1728125000000001
# Optimization terminated successfully.
#          Current function value: -0.244007
#          Iterations: 20
#          Function evaluations: 40
# -0.1600000000000001
# Optimization terminated successfully.
#          Current function value: -0.108916
#          Iterations: 19
#          Function evaluations: 38
# -0.1463750000000001
# Optimization terminated successfully.
#          Current function value: 0.038742
#          Iterations: 19
#          Function evaluations: 38
# -0.13181250000000005
# Optimization terminated successfully.
#          Current function value: 0.199291
#          Iterations: 19
#          Function evaluations: 38
# -0.11643750000000005

# %%
for ys in [-0.001, 0.0, 0.001]:
  fun = lambda z: loss(ys, z)
  print(fmin(fun, 0.0)[0])
# Out:
# Optimization terminated successfully.
#          Current function value: -0.000005
#          Iterations: 5
#          Function evaluations: 10
# 0.00075
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 3
#          Function evaluations: 6
# 0.0
# Optimization terminated successfully.
#          Current function value: -0.000005
#          Iterations: 6
#          Function evaluations: 12
# -0.00075

# %%
0.00075/0.001
# Out:
# 0.75

# %%
coordinates = np.vstack([y_range, zs, cs]).T

# %%
for i in coordinates:
  print('(', i[0],',', i[1],',', i[2], ')')
# Out:
# ( -1.0 , 0.11643750000000008 , 0.19929058690133655 )
# ( -0.9797979797979798 , 0.13181250000000008 , 0.038741645369799516 )
# ( -0.9595959595959596 , 0.1463750000000001 , -0.1089163601216957 )
# ( -0.9393939393939394 , 0.16000000000000011 , -0.24400702940268687 )
# ( -0.9191919191919192 , 0.17281250000000012 , -0.3668744129004933 )
# ( -0.898989898989899 , 0.18487500000000012 , -0.4778798594469174 )
# ( -0.8787878787878788 , 0.19612500000000016 , -0.5773993686159185 )
# ( -0.8585858585858586 , 0.20668750000000016 , -0.6658213986991623 )
# ( -0.8383838383838383 , 0.21650000000000016 , -0.7435450058555371 )
# ( -0.8181818181818181 , 0.22556250000000017 , -0.8109782855733767 )
# ( -0.797979797979798 , 0.2339375000000002 , -0.8685370171868662 )
# ( -0.7777777777777778 , 0.2416250000000002 , -0.9166435441884002 )
# ( -0.7575757575757576 , 0.24856250000000019 , -0.9557258039799451 )
# ( -0.7373737373737373 , 0.2548125000000002 , -0.9862164639502419 )
# ( -0.7171717171717171 , 0.2603125000000003 , -1.008552234487507 )
# ( -0.696969696969697 , 0.2651250000000003 , -1.0231732282813855 )
# ( -0.6767676767676767 , 0.26918750000000025 , -1.0305224158000201 )
# ( -0.6565656565656566 , 0.27256250000000026 , -1.0310451541886876 )
# ( -0.6363636363636364 , 0.2751250000000003 , -1.0251887199523944 )
# ( -0.6161616161616161 , 0.27700000000000025 , -1.0134019206094995 )
# ( -0.5959595959595959 , 0.27806250000000027 , -0.9961346762384692 )
# ( -0.5757575757575757 , 0.2783125000000003 , -0.9738376084381851 )
# ( -0.5555555555555556 , 0.27781250000000024 , -0.9469615914425762 )
# ( -0.5353535353535352 , 0.2765000000000003 , -0.9159572841813832 )
# ( -0.5151515151515151 , 0.27437500000000026 , -0.8812745714172052 )
# ( -0.4949494949494949 , 0.2715000000000003 , -0.8433619491549269 )
# ( -0.4747474747474747 , 0.26775000000000027 , -0.8026657990727442 )
# ( -0.4545454545454545 , 0.26325000000000026 , -0.7596295738509651 )
# ( -0.43434343434343425 , 0.25793750000000026 , -0.7146928658985386 )
# ( -0.41414141414141414 , 0.2518125000000002 , -0.6682903637729782 )
# ( -0.3939393939393939 , 0.2449375000000002 , -0.6208506783562445 )
# ( -0.3737373737373737 , 0.23725000000000018 , -0.5727950895529166 )
# ( -0.3535353535353535 , 0.22887500000000016 , -0.5245361748835704 )
# ( -0.33333333333333326 , 0.21981250000000016 , -0.4764763606480755 )
# ( -0.31313131313131304 , 0.21006250000000015 , -0.4290064137562516 )
# ( -0.2929292929292928 , 0.19962500000000016 , -0.38250391263645594 )
# ( -0.2727272727272727 , 0.18856250000000013 , -0.3373316643987178 )
# ( -0.2525252525252525 , 0.17700000000000013 , -0.2938361766562667 )
# ( -0.23232323232323226 , 0.1648125000000001 , -0.25234612830470676 )
# ( -0.21212121212121204 , 0.15218750000000011 , -0.2131708967608827 )
# ( -0.19191919191919182 , 0.1390625000000001 , -0.17659919016517275 )
# ( -0.1717171717171716 , 0.12550000000000008 , -0.1428977143852838 )
# ( -0.1515151515151515 , 0.11162500000000007 , -0.11230999985467253 )
# ( -0.13131313131313127 , 0.09743750000000007 , -0.08505527091528042 )
# ( -0.11111111111111105 , 0.08287500000000005 , -0.06132750370860351 )
# ( -0.09090909090909083 , 0.06818750000000004 , -0.04129454397616097 )
# ( -0.07070707070707061 , 0.05318750000000002 , -0.02509738385974268 )
# ( -0.050505050505050386 , 0.03812500000000001 , -0.012849545675490992 )
# ( -0.030303030303030276 , 0.022937500000000006 , -0.004636591597284385 )
# ( -0.010101010101010055 , 0.007625000000000003 , -0.0005157738068841985 )
# ( 0.010101010101010166 , -0.007625000000000002 , -0.0005157738068842099 )
# ( 0.030303030303030498 , -0.022937500000000006 , -0.0046365915972844535 )
# ( 0.05050505050505061 , -0.03812500000000001 , -0.012849545675491101 )
# ( 0.07070707070707072 , -0.053187500000000006 , -0.025097383859742764 )
# ( 0.09090909090909105 , -0.06818750000000001 , -0.041294543976161155 )
# ( 0.11111111111111116 , -0.08287500000000002 , -0.06132750370860361 )
# ( 0.1313131313131315 , -0.09743750000000004 , -0.08505527091528069 )
# ( 0.1515151515151516 , -0.11162500000000004 , -0.11230999985467273 )
# ( 0.1717171717171717 , -0.12550000000000006 , -0.142897714385284 )
# ( 0.19191919191919204 , -0.13906250000000006 , -0.17659919016517314 )
# ( 0.21212121212121215 , -0.1521875000000001 , -0.2131708967608829 )
# ( 0.2323232323232325 , -0.16481250000000008 , -0.25234612830470726 )
# ( 0.2525252525252526 , -0.1770000000000001 , -0.29383617665626693 )
# ( 0.27272727272727293 , -0.1885625000000001 , -0.33733166439871826 )
# ( 0.29292929292929304 , -0.1996250000000001 , -0.3825039126364562 )
# ( 0.31313131313131315 , -0.21006250000000012 , -0.42900641375625187 )
# ( 0.3333333333333335 , -0.21981250000000013 , -0.476476360648076 )
# ( 0.3535353535353536 , -0.22887500000000016 , -0.5245361748835706 )
# ( 0.3737373737373739 , -0.23725000000000016 , -0.572795089552917 )
# ( 0.39393939393939403 , -0.24493750000000017 , -0.6208506783562447 )
# ( 0.41414141414141437 , -0.25181250000000016 , -0.6682903637729788 )
# ( 0.4343434343434345 , -0.25793750000000015 , -0.7146928658985392 )
# ( 0.4545454545454546 , -0.2632500000000002 , -0.7596295738509652 )
# ( 0.4747474747474749 , -0.26775000000000015 , -0.8026657990727447 )
# ( 0.49494949494949503 , -0.2715000000000002 , -0.843361949154927 )
# ( 0.5151515151515154 , -0.2743750000000002 , -0.8812745714172052 )
# ( 0.5353535353535355 , -0.2765000000000002 , -0.9159572841813834 )
# ( 0.5555555555555556 , -0.2778125000000002 , -0.9469615914425762 )
# ( 0.5757575757575759 , -0.2783125000000002 , -0.9738376084381856 )
# ( 0.595959595959596 , -0.2780625000000002 , -0.9961346762384693 )
# ( 0.6161616161616164 , -0.2770000000000002 , -1.0134019206094997 )
# ( 0.6363636363636365 , -0.2751250000000002 , -1.0251887199523944 )
# ( 0.6565656565656568 , -0.27256250000000015 , -1.0310451541886876 )
# ( 0.6767676767676769 , -0.2691875000000002 , -1.0305224158000201 )
# ( 0.696969696969697 , -0.26512500000000017 , -1.0231732282813855 )
# ( 0.7171717171717173 , -0.26031250000000017 , -1.008552234487507 )
# ( 0.7373737373737375 , -0.25481250000000016 , -0.9862164639502418 )
# ( 0.7575757575757578 , -0.24856250000000016 , -0.9557258039799447 )
# ( 0.7777777777777779 , -0.24162500000000015 , -0.9166435441884001 )
# ( 0.7979797979797982 , -0.23393750000000016 , -0.8685370171868655 )
# ( 0.8181818181818183 , -0.22556250000000014 , -0.8109782855733764 )
# ( 0.8383838383838385 , -0.21650000000000014 , -0.7435450058555365 )
# ( 0.8585858585858588 , -0.20668750000000014 , -0.6658213986991616 )
# ( 0.8787878787878789 , -0.1961250000000001 , -0.5773993686159178 )
# ( 0.8989898989898992 , -0.18487500000000012 , -0.47787985944691647 )
# ( 0.9191919191919193 , -0.1728125000000001 , -0.3668744129004925 )
# ( 0.9393939393939394 , -0.1600000000000001 , -0.24400702940268681 )
# ( 0.9595959595959598 , -0.1463750000000001 , -0.108916360121694 )
# ( 0.9797979797979799 , -0.13181250000000005 , 0.03874164536979957 )
# ( 1.0 , -0.11643750000000005 , 0.1992905869013366 )

# %%
for i in coordinates:
  print('(', i[0],',', i[1],',', 6, ')')
# Out:
# ( -1.0 , 0.11643750000000008 , 6 )
# ( -0.9797979797979798 , 0.13181250000000008 , 6 )
# ( -0.9595959595959596 , 0.1463750000000001 , 6 )
# ( -0.9393939393939394 , 0.16000000000000011 , 6 )
# ( -0.9191919191919192 , 0.17281250000000012 , 6 )
# ( -0.898989898989899 , 0.18487500000000012 , 6 )
# ( -0.8787878787878788 , 0.19612500000000016 , 6 )
# ( -0.8585858585858586 , 0.20668750000000016 , 6 )
# ( -0.8383838383838383 , 0.21650000000000016 , 6 )
# ( -0.8181818181818181 , 0.22556250000000017 , 6 )
# ( -0.797979797979798 , 0.2339375000000002 , 6 )
# ( -0.7777777777777778 , 0.2416250000000002 , 6 )
# ( -0.7575757575757576 , 0.24856250000000019 , 6 )
# ( -0.7373737373737373 , 0.2548125000000002 , 6 )
# ( -0.7171717171717171 , 0.2603125000000003 , 6 )
# ( -0.696969696969697 , 0.2651250000000003 , 6 )
# ( -0.6767676767676767 , 0.26918750000000025 , 6 )
# ( -0.6565656565656566 , 0.27256250000000026 , 6 )
# ( -0.6363636363636364 , 0.2751250000000003 , 6 )
# ( -0.6161616161616161 , 0.27700000000000025 , 6 )
# ( -0.5959595959595959 , 0.27806250000000027 , 6 )
# ( -0.5757575757575757 , 0.2783125000000003 , 6 )
# ( -0.5555555555555556 , 0.27781250000000024 , 6 )
# ( -0.5353535353535352 , 0.2765000000000003 , 6 )
# ( -0.5151515151515151 , 0.27437500000000026 , 6 )
# ( -0.4949494949494949 , 0.2715000000000003 , 6 )
# ( -0.4747474747474747 , 0.26775000000000027 , 6 )
# ( -0.4545454545454545 , 0.26325000000000026 , 6 )
# ( -0.43434343434343425 , 0.25793750000000026 , 6 )
# ( -0.41414141414141414 , 0.2518125000000002 , 6 )
# ( -0.3939393939393939 , 0.2449375000000002 , 6 )
# ( -0.3737373737373737 , 0.23725000000000018 , 6 )
# ( -0.3535353535353535 , 0.22887500000000016 , 6 )
# ( -0.33333333333333326 , 0.21981250000000016 , 6 )
# ( -0.31313131313131304 , 0.21006250000000015 , 6 )
# ( -0.2929292929292928 , 0.19962500000000016 , 6 )
# ( -0.2727272727272727 , 0.18856250000000013 , 6 )
# ( -0.2525252525252525 , 0.17700000000000013 , 6 )
# ( -0.23232323232323226 , 0.1648125000000001 , 6 )
# ( -0.21212121212121204 , 0.15218750000000011 , 6 )
# ( -0.19191919191919182 , 0.1390625000000001 , 6 )
# ( -0.1717171717171716 , 0.12550000000000008 , 6 )
# ( -0.1515151515151515 , 0.11162500000000007 , 6 )
# ( -0.13131313131313127 , 0.09743750000000007 , 6 )
# ( -0.11111111111111105 , 0.08287500000000005 , 6 )
# ( -0.09090909090909083 , 0.06818750000000004 , 6 )
# ( -0.07070707070707061 , 0.05318750000000002 , 6 )
# ( -0.050505050505050386 , 0.03812500000000001 , 6 )
# ( -0.030303030303030276 , 0.022937500000000006 , 6 )
# ( -0.010101010101010055 , 0.007625000000000003 , 6 )
# ( 0.010101010101010166 , -0.007625000000000002 , 6 )
# ( 0.030303030303030498 , -0.022937500000000006 , 6 )
# ( 0.05050505050505061 , -0.03812500000000001 , 6 )
# ( 0.07070707070707072 , -0.053187500000000006 , 6 )
# ( 0.09090909090909105 , -0.06818750000000001 , 6 )
# ( 0.11111111111111116 , -0.08287500000000002 , 6 )
# ( 0.1313131313131315 , -0.09743750000000004 , 6 )
# ( 0.1515151515151516 , -0.11162500000000004 , 6 )
# ( 0.1717171717171717 , -0.12550000000000006 , 6 )
# ( 0.19191919191919204 , -0.13906250000000006 , 6 )
# ( 0.21212121212121215 , -0.1521875000000001 , 6 )
# ( 0.2323232323232325 , -0.16481250000000008 , 6 )
# ( 0.2525252525252526 , -0.1770000000000001 , 6 )
# ( 0.27272727272727293 , -0.1885625000000001 , 6 )
# ( 0.29292929292929304 , -0.1996250000000001 , 6 )
# ( 0.31313131313131315 , -0.21006250000000012 , 6 )
# ( 0.3333333333333335 , -0.21981250000000013 , 6 )
# ( 0.3535353535353536 , -0.22887500000000016 , 6 )
# ( 0.3737373737373739 , -0.23725000000000016 , 6 )
# ( 0.39393939393939403 , -0.24493750000000017 , 6 )
# ( 0.41414141414141437 , -0.25181250000000016 , 6 )
# ( 0.4343434343434345 , -0.25793750000000015 , 6 )
# ( 0.4545454545454546 , -0.2632500000000002 , 6 )
# ( 0.4747474747474749 , -0.26775000000000015 , 6 )
# ( 0.49494949494949503 , -0.2715000000000002 , 6 )
# ( 0.5151515151515154 , -0.2743750000000002 , 6 )
# ( 0.5353535353535355 , -0.2765000000000002 , 6 )
# ( 0.5555555555555556 , -0.2778125000000002 , 6 )
# ( 0.5757575757575759 , -0.2783125000000002 , 6 )
# ( 0.595959595959596 , -0.2780625000000002 , 6 )
# ( 0.6161616161616164 , -0.2770000000000002 , 6 )
# ( 0.6363636363636365 , -0.2751250000000002 , 6 )
# ( 0.6565656565656568 , -0.27256250000000015 , 6 )
# ( 0.6767676767676769 , -0.2691875000000002 , 6 )
# ( 0.696969696969697 , -0.26512500000000017 , 6 )
# ( 0.7171717171717173 , -0.26031250000000017 , 6 )
# ( 0.7373737373737375 , -0.25481250000000016 , 6 )
# ( 0.7575757575757578 , -0.24856250000000016 , 6 )
# ( 0.7777777777777779 , -0.24162500000000015 , 6 )
# ( 0.7979797979797982 , -0.23393750000000016 , 6 )
# ( 0.8181818181818183 , -0.22556250000000014 , 6 )
# ( 0.8383838383838385 , -0.21650000000000014 , 6 )
# ( 0.8585858585858588 , -0.20668750000000014 , 6 )
# ( 0.8787878787878789 , -0.1961250000000001 , 6 )
# ( 0.8989898989898992 , -0.18487500000000012 , 6 )
# ( 0.9191919191919193 , -0.1728125000000001 , 6 )
# ( 0.9393939393939394 , -0.1600000000000001 , 6 )
# ( 0.9595959595959598 , -0.1463750000000001 , 6 )
# ( 0.9797979797979799 , -0.13181250000000005 , 6 )
# ( 1.0 , -0.11643750000000005 , 6 )

# %%
import numpy as np

def f(x, y):
    return (4 - 2.1*(np.sin(15)*x + np.cos(15)*y)**2 + (np.sin(15)*x + np.cos(15)*y)**4/3)*(np.sin(15)*x + np.cos(15)*y)**2 + (np.sin(15)*x + np.cos(15)*y)*(np.cos(15)*x - np.sin(15)*y)+(-4 + 4*(np.cos(15)*x - np.sin(15)*y)**2)*(np.cos(15)*x - np.sin(15)*y)**2

result = f(-1, -2)
print("Result:", result)
# Out:
# Result: 58.84808833816323

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
X = np.arange(-1, 1, 0.01)
Y = np.arange(-2, 2, 0.01)
X, Y = np.meshgrid(X, Y)
Z = f(X, Y)
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0)
ax.scatter(*coordinates.T)
